# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time
options = webdriver.ChromeOptions()
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(options=options)
url = "https://www.metacritic.com/browse/tv/"
driver.get(url)


# scroll window
# driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
# time.sleep(3)  # espera o JS injetar as imagens

for i in range(5):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)

soup = BeautifulSoup(driver.page_source, "html.parser")
tv_shows = soup.find_all(class_="c-finderProductCard")
img_urls = []
for show in tv_shows[:5]:
    img_tag = show.find("img")
    if img_tag and img_tag.get("src"):
        img_urls.append(img_tag["src"])


print(img_urls)
# Out:
# ['https://www.metacritic.com/a/img/resize/35590ad56d77635bd062aacb028fb5cdce98df3e/catalog/provider/2/2/2-bda5bbc8e07f93f9e60353b98cd2e67a.jpg?auto=webp&fit=cover&height=132&width=88', 'https://www.metacritic.com/a/img/resize/28a62562ee72bb8d509d9014e126ac79064c59da/catalog/provider/2/2/2-1fec3b983df97cc1748846b3a50306f2.jpg?auto=webp&fit=cover&height=132&width=88']

# %%
# !pip install selenium
# Out:
# ...
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.6 MB 1.2 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/9.6 MB 1.2 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/9.6 MB 1.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/9.6 MB 1.1 MB/s eta 0:00:08
#    ------ --------------------------------- 1.6/9.6 MB 1.1 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.6 MB 1.1 MB/s eta 0:00:07
#    -------- ------------------------------- 2.1/9.6 MB 1.1 MB/s eta 0:00:07
#    --------- ------------------------------ 2.4/9.6 MB 1.1 MB/s eta 0:00:07
# ...
